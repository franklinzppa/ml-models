# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris

# %%
# Load Iris
iris = load_iris()
X = iris['data'][:,2:]
y = iris['target']

# Getting only species 1 and 2
X = X[(y==1)+(y==2)]
y = y[(y==1)+(y==2)]

# Setting y to be 0 or 1
y = y-1

# %%
plt.scatter(X[:,0], X[:,1], c=y)
plt.show()

# %%
def sigmoid(t):
    """Sigmoid function."""
    return 1 / (1 + np.exp(-t))

# %%
@np.vectorize
def predict(p):
    if p < 0.5:
        return 0.0
    else:
        return 1.0

# %%
t = np.linspace(-10, 10)

plt.plot(t, sigmoid(t))
plt.xlabel('t')
plt.ylabel('$\sigma(t)$')
plt.grid()
plt.show()

# %%
# Gradient of the cost function
np.random.seed(42)
m,n = X.shape

eta = 0.1
theta = np.random.rand(n+1)

max_steps = 1500

# Add ones to X array
X_bias = np.c_[np.ones(m), X]

for i in range(max_steps):
    # Calculate grad J
    gradJ = (1/m) * X_bias.T.dot(sigmoid(X_bias@theta)-y)
    # Update theta 
    theta = theta - (eta*gradJ)

# %%
x_values = [3,7]
y_values = - (theta[0] + np.dot(theta[1], x_values)) / theta[2]
plt.scatter(X[:,0], X[:,1], c=y)
plt.plot(x_values, y_values, label='Decision Boundary')
plt.show()
